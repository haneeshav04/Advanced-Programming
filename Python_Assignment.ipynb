# %% [markdown]
# <a href="https://colab.research.google.com/github/haneeshav04/Advanced-Programming/blob/master/Python_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1:
# Print ManOfMach count of each player in Hyderabad stadium

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
df
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 0           0    335987  ...      140.0          1
# 1           1    335988  ...       33.0          1
# 2           2    335989  ...        9.0          1
# 3           3    335990  ...        5.0          1
# 4           4    335991  ...        5.0          1
# ..        ...       ...  ...        ...        ...
# 632       632   1082646  ...       10.0          1
# 633       633   1082647  ...       20.0          1
# 634       634   1082648  ...        7.0          1
# 635       635   1082649  ...        6.0          1
# 636       636   1082650  ...        1.0          1
#
# [637 rows x 17 columns]

# %%
s=df.loc[df['City_Name']=='Hyderabad']['ManOfMach'].value_counts()
s
# Out:
# DA Warner            6
# DW Steyn             3
# SK Raina             2
# V Sehwag             2
# A Mishra             2
# YK Pathan            2
# GH Vihari            2
# SL Malinga           1
# SC Ganguly           1
# B Kumar              1
# UT Yadav             1
# Mustafizur Rahman    1
# AT Rayudu            1
# MJ McClenaghan       1
# V Kohli              1
# WP Saha              1
# SK Trivedi           1
# I Sharma             1
# G Gambhir            1
# SE Marsh             1
# CH Morris            1
# Mandeep Singh        1
# PA Patel             1
# R Vinay Kumar        1
# DJ Bravo             1
# AB Dinda             1
# PC Valthaty          1
# MR Marsh             1
# DJG Sammy            1
# Name: ManOfMach, dtype: int64

# %% [markdown]
# # Question 2:
# Plot a pie chart for the country_name column

# %%
import matplotlib.pyplot as plt
exp_vals = [87.90,8.90,3.1]
exp_labels = ["India","South Africa","U.A.E"]
plt.pie(exp_vals,labels=exp_labels,autopct='%0.2f%%',radius=1.5,explode=[0,0.1,0.1])
plt.show()
